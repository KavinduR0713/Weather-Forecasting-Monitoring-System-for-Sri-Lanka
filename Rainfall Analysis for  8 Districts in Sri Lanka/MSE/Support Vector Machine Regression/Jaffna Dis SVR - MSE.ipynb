# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Actual values (replace with your actual data)
y_actual = np.array([279,
8,
2,
50,
46,
55,
42,
16,
34,
441,
332,
157,
120,
70,
51,
235,
12,
4,
58,
107,
46,
318,
363,
157,
30,
148,
8,
16,
107,
15,
19,
23
])

# Predicted values from Random Forest Regressor (replace with your actual predicted values)
y_predicted_rf = np.array([37.38465657,
36.77089691,
36.74158153,
37.35887716,
38.57272934,
40.23280927,
42.12214556,
44.00021745,
45.64507345,
46.8882931,
47.63911726,
47.89414958,
39.83929112,
39.46191813,
39.47791955,
39.92361626,
40.75761101,
41.870319,
43.10968746,
44.31375167,
45.34096296,
46.09245367,
46.52379505,
46.64581878,
41.92440064,
41.72750797,
41.75433378,
42.02327754,
42.50759529,
43.14137491,
43.83541456,
44.4972317
])

# Calculate Mean Squared Error (MSE)
mse_rf = mean_squared_error(y_actual, y_predicted_rf)

# Print the result
print("Mean Squared Error (MSE) for Random Forest Regressor:", mse_rf)
# Out:
# Mean Squared Error (MSE) for Random Forest Regressor: 17730.15789274667
