# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Actual values (replace with your actual data)
y_actual = np.array([160,
23,
134,
205,
507,
266,
165,
198,
250,
445,
627,
60,
27,
39,
92,
306,
402,
83,
150,
288,
203,
421,
337,
257,
57,
65,
205,
279,
146,
162,
106,
75
])

# Predicted values from Random Forest Regressor (replace with your actual predicted values)
y_predicted_rf = np.array([158.9207145,
158.838378,
159.0095726,
159.4114668,
160.0070653,
160.7624141,
161.6451866,
162.6065041,
163.5632801,
164.4005879,
165.0000477,
165.2811973,
160.176388,
160.1086727,
160.2036401,
160.44991,
160.8266495,
161.3137557,
161.8906061,
162.5245788,
163.1601374,
163.720699,
164.1271254,
164.324689,
161.179854,
161.1324185,
161.17456,
161.3011943,
161.5020332,
161.7670148,
162.0855006,
162.4398612
])

# Calculate Mean Squared Error (MSE)
mse_rf = mean_squared_error(y_actual, y_predicted_rf)

# Print the result
print("Mean Squared Error (MSE) for Random Forest Regressor:", mse_rf)
# Out:
# Mean Squared Error (MSE) for Random Forest Regressor: 23631.631535344633
